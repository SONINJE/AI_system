# %% [markdown]
# <a href="https://colab.research.google.com/github/SONINJE/AI_system/blob/main/Assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
from matplotlib import pyplot as plt

### Tensorflow 2.0 ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import Input
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import regularizers
from tensorflow.keras import utils

# %%
first_layer = Input(shape=(128, 128, 1))

# %%
second_layer = layers.Conv2D(filters=16, kernel_size=(3, 3), activation=None, padding='same')(first_layer)

# %%
third_layer = layers.MaxPool2D(strides=(2, 2))(second_layer)

# %%
fourth_layer =  layers.Conv2D(filters=32, kernel_size=(3, 3), activation=None, padding='same')(third_layer)

# %%
fifth_layer = layers.MaxPool2D(strides=(2, 2))(fourth_layer)

# %%
sixth_layer = layers.Conv2D(filters=64, kernel_size=(3, 3), activation=None, padding='same')(fifth_layer)

# %%
seventh_layer = layers.MaxPool2D(strides=(2, 2))(sixth_layer)

# %%
eighth_layer = layers.Flatten()(seventh_layer)

# %%
ninth_layer = layers.Dense(128, activation = 'relu')(eighth_layer)

# %%
ten_layer = layers.Dropout(0.25)(ninth_layer)

# %%
final_layer =  layers.Dense(5, activation='sigmoid')(ten_layer)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_15 (InputLayer)       [(None, 128, 128, 1)]     0
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 16)      160
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 32)        4640
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 16384)             0
#
#  dense_22 (Dense)            (None, 128)               2097280
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_23 (Dense)            (None, 5)                 645
#
# ...
# Total params: 2,121,221
# Trainable params: 2,121,221
# Non-trainable params: 0
# ...
