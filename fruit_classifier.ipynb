# %% [markdown]
# <a href="https://colab.research.google.com/github/SONINJE/AI_system/blob/main/fruit_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ''' Fruit_classifier'''

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/My Drive
# Out:
# /content/drive/My Drive

# %%
pwd
# Out:
# '/content/drive/My Drive'

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import csv

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import cv2 as cv

# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator

# %%
import pathlib

data_dir = './fruit'

data_dir = pathlib.Path(data_dir)

# %%
trdata = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True, validation_split=0.2)


traindata = trdata.flow_from_directory(directory="/content/drive/MyDrive/fruit",   target_size=(256,256), subset='training')

valdata = trdata.flow_from_directory(directory="/content/drive/MyDrive/fruit",   target_size=(256,256),subset="validation" ,)
# Out:
# Found 240 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 300

# %%
train = list(data_dir.glob('train/*'))
PIL.Image.open(str(train[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x797 at 0x7F999A5A9950>

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  image_size=(256, 256),
  seed = 1,
  batch_size=240)
# Out:
# Found 300 files belonging to 2 classes.
# Using 240 files for training.
